# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
URL = 'https://overpass-api.de/api/interpreter'

# Overpass turbo query
QUERY = """
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request (falls back to a local cache if the Overpass server can't be reached)
try:
    r = requests.get(
        URL,
        params={'data': QUERY},
        headers={'User-Agent': 'my-app/1.0'},
        timeout=30
    )
    r.raise_for_status()
    data = r.json()['elements']

    # Save data to file
    with open('supermarkets.json', 'w', encoding="utf-8") as json_file:
        json.dump(data, json_file)
except (requests.RequestException, ValueError) as e:
    print(f"Overpass API request failed ({e}); loading cached supermarkets.json instead.")
    with open('supermarkets.json') as json_file:
        data = json.load(json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# Overpass API request failed (406 Client Error: Not Acceptable for url: https://overpass-api.de/api/interpreter?data=%0A++++++++%5Bout%3Ajson%5D%3B%0A++++++++area%5B%22ISO3166-1%22%3D%22CH%22%5D%5Badmin_level%3D2%5D%3B%0A++++++++node+%5B%22shop%22%3D%22supermarket%22%5D%28area%29%3B%0A++++++++out%3B); loading cached supermarkets.json instead.
# (3392, 237)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225069  8.969981       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.operator:website  \
# 0              NaN               NaN         NaN                   NaN
# 1              NaN               NaN         NaN                   NaN
# 2              NaN               NaN         NaN                   NaN
# 3              NaN               NaN         NaN                   NaN
# 4              NaN               NaN         NaN                   NaN
#
#   tags.diet:local tags.payment:account_cards tags.diet:fish  \
# 0             NaN                        NaN            NaN
# 1             NaN                        NaN            NaN
# 2             NaN                        NaN            NaN
# 3             NaN                        NaN            NaN
# 4             NaN                        NaN            NaN
#
#   tags.diet:mediterranean tags.diet:organic tags.diet:seafood
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
# 3                     NaN               NaN               NaN
# 4                     NaN               NaN               NaN
#
# [5 rows x 237 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225069  8.969981       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15491fde208773cc632939783910dee5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15491fde208773cc632939783910dee5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15491fde208773cc632939783910dee5 = L.map(
#                 &quot;map_15491fde208773cc632939783910dee5&quot;,
#                 {
#                     center: [47.009678141875, 7.990980280625],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_15491fde208773cc632939783910dee5);
#
#
#
#
#
#             var tile_layer_96a142ccda87dbc59048ea9efb26c3f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_96a142ccda87dbc59048ea9efb26c3f8.addTo(map_15491fde208773cc632939783910dee5);
#
#
#             var marker_e57b1f0d45f39c9d95dfa91f7debe162 = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_15491fde208773cc632939783910dee5);
#
#
#         var popup_1cc8649f2ca1d73fb8abfa2dc563bd2e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f14b09bd2814b60b1021fcdf87b988f3 = $(`&lt;div id=&quot;html_f14b09bd2814b60b1021fcdf87b988f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_1cc8649f2ca1d73fb8abfa2dc563bd2e.setContent(html_f14b09bd2814b60b1021fcdf87b988f3);
#
#
#
#         marker_e57b1f0d45f39c9d95dfa91f7debe162.bindPopup(popup_1cc8649f2ca1d73fb8abfa2dc563bd2e)
#         ;
#
#
#
#
#             var marker_837a700d46f3f5c4819aae8046da4ec8 = L.marker(
#                 [47.2250689, 8.9699805],
#                 {}
#             ).addTo(map_15491fde208773cc632939783910dee5);
#
#
#         var popup_dc8d8ed92309a6f0d3cea345185f73aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1283eaaf1a61474f20dc9c2d27daaac9 = $(`&lt;div id=&quot;html_1283eaaf1a61474f20dc9c2d27daaac9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_dc8d8ed92309a6f0d3cea345185f73aa.setContent(html_1283eaaf1a61474f20dc9c2d27daaac9);
#
#
#
#         marker_837a700d46f3f5c4819aae8046da4ec8.bindPopup(popup_dc8d8ed92309a6f0d3cea345185f73aa)
#         ;
#
#
#
#
#             var marker_ecf96ae19c04b5edb9ef572fc5175b9d = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_15491fde208773cc632939783910dee5);
#
#
#         var popup_e337fa38cdf689ed66174455a7fc48ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c22002e252497ae042c0a7bf18fca78a = $(`&lt;div id=&quot;html_c22002e252497ae042c0a7bf18fca78a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_e337fa38cdf689ed66174455a7fc48ec.setContent(html_c22002e252497ae042c0a7bf18fca78a);
#
#
#
#         marker_ecf96ae19c04b5edb9ef572fc5175b9d.bindPopup(popup_e337fa38cdf689ed66174455a7fc48ec)
#         ;
#
#
#
#
#             var marker_f9dfe4cbf7ff6d7cfaf3009957196767 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_15491fde208773cc632939783910dee5);
#
#
#         var popup_e34498d99f3b921745dce498c24f1a55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d1c54f16260ddad003a056db745a9e4a = $(`&lt;div id=&quot;html_d1c54f16260ddad003a056db745a9e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_e34498d99f3b921745dce498c24f1a55.setContent(html_d1c54f16260ddad003a056db745a9e4a);
#
#
#
#         marker_f9dfe4cbf7ff6d7cfaf3009957196767.bindPopup(popup_e34498d99f3b921745dce498c24f1a55)
#         ;
#
#
#
#
#             var marker_9aafda1d6a255bb6b55e3388a488f78a = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_15491fde208773cc632939783910dee5);
#
#
#         var popup_894996b8d9b8389b79e034b8faa6dd4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_27106366f4ad2d4802cc48d9c752f65b = $(`&lt;div id=&quot;html_27106366f4ad2d4802cc48d9c752f65b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_894996b8d9b8389b79e034b8faa6dd4f.setContent(html_27106366f4ad2d4802cc48d9c752f65b);
#
#
#
#         marker_9aafda1d6a255bb6b55e3388a488f78a.bindPopup(popup_894996b8d9b8389b79e034b8faa6dd4f)
#         ;
#
#
#
#
#             var marker_484d087ed8933d74dcfb2e01cc09d70b = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1064-azure
# Datetime: 2026-09-17 11:18:34
# Python Version: 3.11.16
# -----------------------------------
